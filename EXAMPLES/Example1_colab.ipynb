# %% [markdown]
# <a href="https://colab.research.google.com/github/Martindelosrios/pyROGER/blob/dev/EXAMPLES/Example1_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Let's load the needed libraries

# %%
pip install pyroger
# Out:
# Requirement already satisfied: pyroger in /usr/local/lib/python3.12/dist-packages (0.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pyroger) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from pyroger) (3.10.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from pyroger) (1.6.1)
# Requirement already satisfied: mlxtend in /usr/local/lib/python3.12/dist-packages (from pyroger) (0.23.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from pyroger) (2.2.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from pyroger) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pyroger) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pyroger) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pyroger) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pyroger) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pyroger) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pyroger) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pyroger) (3.2.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->pyroger) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from mlxtend->pyroger) (1.16.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->pyroger) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->pyroger) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->pyroger) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->pyroger) (1.17.0)

# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk
import pandas as pd
import importlib.resources

with importlib.resources.path("pyROGER", "dataset") as p:
    DATA_PATH = str(p)


from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

from sklearn.neighbors import KNeighborsClassifier
from sklearn import svm

from mlxtend.plotting import plot_confusion_matrix

from pyROGER import roger
from pyROGER import models

# %%
# Color scheme
cl_col  = 'red'
rin_col = 'green'
bs_col  = 'orange'
inf_col = 'blue'
itl_col = 'gray'

labels = ['CL', 'RIN', 'BS', 'IN', 'ITL']

# %% [markdown]
# # Let's load the data

# %%
# Old ROGER 1 data
data = pd.read_csv(DATA_PATH + '/highmass_testset_roger1.csv', sep = ' ')
data = np.asarray(data)

data[np.where(data[:,2] == 'CL')[0], 2] = 0
data[np.where(data[:,2] == 'RIN')[0], 2] = 1
data[np.where(data[:,2] == 'BS')[0], 2] = 2
data[np.where(data[:,2] == 'IN')[0], 2] = 3
data[np.where(data[:,2] == 'ITL')[0], 2] = 4
data = data.astype('float64')

cl  = data[np.where(data[:,2] == 0)[0]]
rin = data[np.where(data[:,2] == 1)[0]]
bs  = data[np.where(data[:,2] == 2)[0]]
inf = data[np.where(data[:,2] == 3)[0]]
itl = data[np.where(data[:,2] == 4)[0]]

print('Hay ' + str(len(cl)) + ' cluster galaxies')
print('Hay ' + str(len(rin)) + ' recent infalling galaxies')
print('Hay ' + str(len(bs)) + ' backsplash galaxies')
print('Hay ' + str(len(inf)) + ' infalling galaxies')
print('Hay ' + str(len(itl)) + ' interlooper galaxies')
# Out:
# Hay 343 cluster galaxies
# Hay 308 recent infalling galaxies
# Hay 526 backsplash galaxies
# Hay 837 infalling galaxies
# Hay 916 interlooper galaxies

# %%
plt.scatter(inf[:,0], inf[:,1], c = inf_col, marker = '<')
plt.scatter(itl[:,0], itl[:,1], c = itl_col, marker = '>')
plt.scatter(cl[:,0], cl[:,1], c = cl_col)
plt.scatter(rin[:,0], rin[:,1], c = rin_col, marker = '+')
plt.scatter(bs[:,0], bs[:,1], c = bs_col, marker = '*')
plt.xlabel('r')
plt.xlabel('v')
# Out:
# Text(0.5, 0, 'v')

# %% [markdown]
# # Let's play with ROGER

# %%
# First we can check which models are available
models.list_saved_models()
# Out:
# ['/usr/local/lib/python3.12/dist-packages/pyROGER/dataset/HighMassRoger1_RF.joblib',
#  '/usr/local/lib/python3.12/dist-packages/pyROGER/dataset/HighMassRoger1_SVM.joblib',
#  '/usr/local/lib/python3.12/dist-packages/pyROGER/dataset/HighMassRoger1_KNN.joblib',
#  '/usr/local/lib/python3.12/dist-packages/pyROGER/dataset/roger2_KNN.joblib']

# %%
# Inside each model should be a tiny explanation of how to use it.
#---------------------------------------------------------------------------
#    BE CAREFUL: IF THE MODEL IS ALREADY TRAINED AND READY TO USE THERE WILL
#    BE A FLAG AT THE END LEETING YOU KNOW!!!
#---------------------------------------------------------------------------

models.HighMassRoger1
# Out:
#  ROGER model for isolated galaxy clusters with masses
# bigger than >10^{13} M_{sun}.
#   This model is equivalent to the one presented in 2010.11959 and
#   in https://mdelosrios.shinyapps.io/roger_shiny/.
#   The saved models located in the datasets are:
#    * HighMassRoger1_RF.joblib
#    * HighMassRoger1_SVM.joblib
#    * HighMassRoger1_KNN.joblib
#
#   The input must be a np.array with shape (Ngal, 2) where,
#   the first column must be the cluster-centric distance normalized to R200,
#   and the second must be the relative velocity normalized to the cluster
#   velocity dispersion, i.e:
#
#     [:,0] = R / R200
#     [:,1] = |\Delta V| / sigma
#
#   The output for predict_prob() is a np.array with shape (Ngal, 5)
#     [:,0] = P_cl: Probability of being a cluster galaxy.
#     [:,1] = P_rin: Probability of being a backsplash galaxy.
#     [:,2] = P_bs: Probability of being a recent infaller galaxy.
#     [:,3] = P_in: Probability of being an infalling galaxy.
#     [:,4] = P_itl: Probability of being a iterloper galaxy.
#
#   The output for predict_class() is a np.array with shape (Ngal, ) with
#   the predicted classes.
#      0: Cluster galaxy
#      1: Recent infaller galaxy
#      2: Backsplash galaxy
#      3: Infalling galaxy
#      4: Iterlooper galaxy
#
#  NOT TRAINED YET

# %%
# For using an available model you can just upload it by giving the path to the corresponding .joblib file.

models.HighMassRoger1.train(path_to_saved_model= [DATA_PATH + '/HighMassRoger1_KNN.joblib',
                                                  None,
                                                  DATA_PATH + '/HighMassRoger1_SVM.joblib'])

# -------------------------------------------------------------------
# THE MODELS WERE TRAINED WITH SCIKIT-LEARN = 1.3.0 !!!!
#
#  If you have a different scikit-learn version you will see a warning for the knn and svm models.
#  For random forest you will probably have an error so it is better just to re-tran it.
#  You can do this just putting None in the path.
# -------------------------------------------------------------------

# If you want to train a new model you will have to do something like:
#     > models.HighMassRoger1.train()
# Out:
# Loading model from: /usr/local/lib/python3.12/dist-packages/pyROGER/dataset/HighMassRoger1_KNN.joblib
# Training ...
# RandomForestClassifier(max_depth=2, random_state=0)
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator KNeighborsClassifier from version 1.3.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# Loading model from: /usr/local/lib/python3.12/dist-packages/pyROGER/dataset/HighMassRoger1_SVM.joblib
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py:380: InconsistentVersionWarning: Trying to unpickle estimator SVC from version 1.3.0 when using version 1.6.1. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
# Just to check that the model is ready to use.
models.HighMassRoger1
# Out:
#  ROGER model for isolated galaxy clusters with masses
# bigger than >10^{13} M_{sun}.
#   This model is equivalent to the one presented in 2010.11959 and
#   in https://mdelosrios.shinyapps.io/roger_shiny/.
#   The saved models located in the datasets are:
#    * HighMassRoger1_RF.joblib
#    * HighMassRoger1_SVM.joblib
#    * HighMassRoger1_KNN.joblib
#
#   The input must be a np.array with shape (Ngal, 2) where,
#   the first column must be the cluster-centric distance normalized to R200,
#   and the second must be the relative velocity normalized to the cluster
#   velocity dispersion, i.e:
#
#     [:,0] = R / R200
#     [:,1] = |\Delta V| / sigma
#
#   The output for predict_prob() is a np.array with shape (Ngal, 5)
#     [:,0] = P_cl: Probability of being a cluster galaxy.
#     [:,1] = P_rin: Probability of being a backsplash galaxy.
#     [:,2] = P_bs: Probability of being a recent infaller galaxy.
#     [:,3] = P_in: Probability of being an infalling galaxy.
#     [:,4] = P_itl: Probability of being a iterloper galaxy.
#
#   The output for predict_class() is a np.array with shape (Ngal, ) with
#   the predicted classes.
#      0: Cluster galaxy
#      1: Recent infaller galaxy
#      2: Backsplash galaxy
#      3: Infalling galaxy
#      4: Iterlooper galaxy
#
#  Ready to use
# Available models:
#
#  n_model:0   KNeighborsClassifier(n_neighbors=63)
#  n_model:1   RandomForestClassifier(max_depth=2, random_state=0)
#  n_model:2   SVC(probability=True)

# %%
real_class = data[:,2]
pred_class = models.HighMassRoger1.predict_class(data[:,(0,1)], 0)
# Out:
# Using model:
# KNeighborsClassifier(n_neighbors=63)  n_model=0

# %%
conf_mat = models.HighMassRoger1.confusion_matrix(real_class, pred_class)[0]
plot_confusion_matrix(conf_mat, show_absolute=True, show_normed=True, class_names=labels)
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: xlabel='predicted label', ylabel='true label'>)
